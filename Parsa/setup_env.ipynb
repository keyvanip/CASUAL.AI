# %%
import os
# Setting working directory
os.chdir("/Users/parsakeyvani/Downloads/spring-2025-final-project-project-group-4-1")
print("Current working directory:", os.getcwd())

################################################################################


# Installing all dependencies at once
# !pip install -r Parsa/requirements.txt
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !pip install -U langchain-community
# installing faiss separately to avoid conflicts
# !conda install -c conda-forge faiss-cpu -y
# Out:
# Current working directory: /Users/parsakeyvani/Downloads/spring-2025-final-project-project-group-4-1
# Requirement already satisfied: torch==2.0.1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: torchvision==0.15.2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 2)) (0.15.2)
# Requirement already satisfied: torchaudio==2.0.2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 3)) (2.0.2)
# Collecting numpy<2.0
#   Using cached numpy-1.26.4-cp310-cp310-macosx_10_9_x86_64.whl (20.6 MB)
# Requirement already satisfied: scikit-learn in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: matplotlib in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 6)) (3.10.1)
# Requirement already satisfied: pillow in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 7)) (11.1.0)
# Requirement already satisfied: faiss-cpu in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 8)) (1.10.0)
# Requirement already satisfied: sentence-transformers in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 9)) (4.0.2)
# Requirement already satisfied: langchain in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 10)) (0.3.23)
# Requirement already satisfied: langchain-community in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 11)) (0.3.21)
# Requirement already satisfied: openai in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 12)) (1.73.0)
# Requirement already satisfied: requests in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 13)) (2.32.3)
# Requirement already satisfied: anthropic in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from -r Parsa/requirements.txt (line 14)) (0.49.0)
# Requirement already satisfied: typing-extensions in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch==2.0.1->-r Parsa/requirements.txt (line 1)) (4.13.0)
# Requirement already satisfied: jinja2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch==2.0.1->-r Parsa/requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: filelock in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch==2.0.1->-r Parsa/requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: sympy in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch==2.0.1->-r Parsa/requirements.txt (line 1)) (1.13.3)
# Requirement already satisfied: networkx in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch==2.0.1->-r Parsa/requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn->-r Parsa/requirements.txt (line 5)) (1.15.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn->-r Parsa/requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from scikit-learn->-r Parsa/requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->-r Parsa/requirements.txt (line 6)) (1.4.8)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->-r Parsa/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->-r Parsa/requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->-r Parsa/requirements.txt (line 6)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->-r Parsa/requirements.txt (line 6)) (3.2.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->-r Parsa/requirements.txt (line 6)) (4.57.0)
# Requirement already satisfied: cycler>=0.10 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from matplotlib->-r Parsa/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers->-r Parsa/requirements.txt (line 9)) (4.51.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers->-r Parsa/requirements.txt (line 9)) (0.30.2)
# Requirement already satisfied: tqdm in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sentence-transformers->-r Parsa/requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain->-r Parsa/requirements.txt (line 10)) (0.3.30)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain->-r Parsa/requirements.txt (line 10)) (2.0.40)
# Requirement already satisfied: PyYAML>=5.3 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain->-r Parsa/requirements.txt (line 10)) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain->-r Parsa/requirements.txt (line 10)) (4.0.3)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.51 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain->-r Parsa/requirements.txt (line 10)) (0.3.51)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain->-r Parsa/requirements.txt (line 10)) (2.11.3)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain->-r Parsa/requirements.txt (line 10)) (0.3.8)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community->-r Parsa/requirements.txt (line 11)) (9.1.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community->-r Parsa/requirements.txt (line 11)) (3.11.16)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community->-r Parsa/requirements.txt (line 11)) (0.6.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community->-r Parsa/requirements.txt (line 11)) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community->-r Parsa/requirements.txt (line 11)) (2.8.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from openai->-r Parsa/requirements.txt (line 12)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from openai->-r Parsa/requirements.txt (line 12)) (0.9.0)
# Requirement already satisfied: sniffio in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from openai->-r Parsa/requirements.txt (line 12)) (1.3.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from openai->-r Parsa/requirements.txt (line 12)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from openai->-r Parsa/requirements.txt (line 12)) (1.9.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests->-r Parsa/requirements.txt (line 13)) (2.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests->-r Parsa/requirements.txt (line 13)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests->-r Parsa/requirements.txt (line 13)) (2025.1.31)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests->-r Parsa/requirements.txt (line 13)) (3.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r Parsa/requirements.txt (line 11)) (2.6.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r Parsa/requirements.txt (line 11)) (25.3.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r Parsa/requirements.txt (line 11)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r Parsa/requirements.txt (line 11)) (1.19.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r Parsa/requirements.txt (line 11)) (1.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r Parsa/requirements.txt (line 11)) (1.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r Parsa/requirements.txt (line 11)) (6.4.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai->-r Parsa/requirements.txt (line 12)) (1.1.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r Parsa/requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r Parsa/requirements.txt (line 11)) (3.26.1)
# Requirement already satisfied: httpcore==1.* in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai->-r Parsa/requirements.txt (line 12)) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r Parsa/requirements.txt (line 12)) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers->-r Parsa/requirements.txt (line 9)) (2025.3.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.51->langchain->-r Parsa/requirements.txt (line 10)) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain->-r Parsa/requirements.txt (line 10)) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain->-r Parsa/requirements.txt (line 10)) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain->-r Parsa/requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain->-r Parsa/requirements.txt (line 10)) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r Parsa/requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r Parsa/requirements.txt (line 10)) (0.4.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r Parsa/requirements.txt (line 10)) (2.33.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community->-r Parsa/requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: six>=1.5 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->-r Parsa/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: greenlet>=1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain->-r Parsa/requirements.txt (line 10)) (3.1.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r Parsa/requirements.txt (line 9)) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r Parsa/requirements.txt (line 9)) (0.5.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers->-r Parsa/requirements.txt (line 9)) (0.21.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->-r Parsa/requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jinja2->torch==2.0.1->-r Parsa/requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sympy->torch==2.0.1->-r Parsa/requirements.txt (line 1)) (1.3.0)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
# Successfully installed numpy-1.26.4
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/parsakeyvani/.pyenv/versions/3.10.0/bin/python3.10 -m pip install --upgrade pip' command.
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: torchvision in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (0.15.2)
# Requirement already satisfied: torchaudio in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (2.0.2)
# Requirement already satisfied: networkx in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: filelock in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: sympy in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch) (1.13.3)
# Requirement already satisfied: typing-extensions in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torch) (4.13.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: requests in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torchvision) (2.32.3)
# Requirement already satisfied: numpy in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests->torchvision) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests->torchvision) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests->torchvision) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests->torchvision) (2.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/parsakeyvani/.pyenv/versions/3.10.0/bin/python3.10 -m pip install --upgrade pip' command.
# Requirement already satisfied: langchain-community in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (0.3.21)
# Requirement already satisfied: PyYAML>=5.3 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community) (0.3.30)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community) (3.11.16)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.51 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community) (0.3.51)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: langchain<1.0.0,>=0.3.23 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community) (0.3.23)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-community) (2.8.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.19.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain<1.0.0,>=0.3.23->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain<1.0.0,>=0.3.23->langchain-community) (2.11.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.51->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.51->langchain-community) (4.13.0)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langchain-core<1.0.0,>=0.3.51->langchain-community) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain-community) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (3.10.16)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: certifi in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (2025.1.31)
# Requirement already satisfied: idna in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (3.10)
# Requirement already satisfied: httpcore==1.* in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.0.8)
# Requirement already satisfied: anyio in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain-community) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.23->langchain-community) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from requests<3,>=2->langchain-community) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/parsakeyvani/.pyenv/versions/3.10.0/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain-community) (1.1.3)
# WARNING: You are using pip version 21.2.3; however, version 25.0.1 is available.
# You should consider upgrading via the '/Users/parsakeyvani/.pyenv/versions/3.10.0/bin/python3.10 -m pip install --upgrade pip' command.
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::conda==23.1.0=py310hecd8cb5_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/parsakeyvani/miniconda3
#
#   added / updated specs:
#     - faiss-cpu
#
#
# The following NEW packages will be INSTALLED:
#
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_1
#   faiss              conda-forge/osx-64::faiss-1.9.0-py310he830de2_0_cpu
#   faiss-cpu          conda-forge/osx-64::faiss-cpu-1.9.0-he781eb1_0
#   libblas            conda-forge/osx-64::libblas-3.9.0-31_h7f60823_openblas
#   libcblas           conda-forge/osx-64::libcblas-3.9.0-31_hff6cab4_openblas
#   libcxx             conda-forge/osx-64::libcxx-20.1.2-hf95d169_0
#   libfaiss           conda-forge/osx-64::libfaiss-1.9.0-h0cb9d5e_0_cpu
#   libgfortran        conda-forge/osx-64::libgfortran-14.2.0-hef36b68_105
#   libgfortran5       conda-forge/osx-64::libgfortran5-14.2.0-h58528f3_105
#   liblapack          conda-forge/osx-64::liblapack-3.9.0-31_h236ab99_openblas
#   libopenblas        conda-forge/osx-64::libopenblas-0.3.29-openmp_hbf64a52_0
#   llvm-openmp        conda-forge/osx-64::llvm-openmp-20.1.2-ha54dae1_0
#   numpy              conda-forge/osx-64::numpy-1.26.4-py310h4bfa8fc_0
#   packaging          conda-forge/noarch::packaging-24.2-pyhd8ed1ab_2
#   pluggy             conda-forge/noarch::pluggy-1.5.0-pyhd8ed1ab_1
#   python_abi         conda-forge/osx-64::python_abi-3.10-2_cp310
#   requests           conda-forge/noarch::requests-2.32.3-pyhd8ed1ab_1
#   setuptools         conda-forge/noarch::setuptools-78.1.0-pyhff2d567_0
#   tqdm               conda-forge/noarch::tqdm-4.67.1-pyhd8ed1ab_1
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2025.1.31-h8857fd0_0
#   certifi            pkgs/main/osx-64::certifi-2022.12.7-p~ --> conda-forge/noarch::certifi-2025.1.31-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-1.1.1s-hca72f7f_0 --> conda-forge::openssl-1.1.1w-h8a1eda9_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'pluggy' is a dependency of conda and cannot be removed from
# conda's operating environment.
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.
# RemoveError: 'setuptools' is a dependency of conda and cannot be removed from
# conda's operating environment.
# RemoveError: 'tqdm' is a dependency of conda and cannot be removed from
# conda's operating environment.
